# %%
# !pip install webdriver-manager
# Out:
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: You are using pip version 20.2.3; however, version 20.3.1 is available.
# You should consider upgrading via the 'C:\Users\Abhishek\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup as soup
import lxml
import requests
from selenium import webdriver
# import smtplib
# import schedule 
import time
from time import sleep
# import threading
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import numpy as np

# %% [markdown]
# ## Making the data to Display for selected 23 varibles with all states data (India).

# %% [markdown]
# ### This Code is only for First 23 Variables

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[:25]

# print(check_box_trail)
for checkbox in check_box_trail:
    checkbox.click()
driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[1]/label').click() #inside state
driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()

# try:
for i in range (0,33):
    i = str(i+1)
    try:
        driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
        i=int(i)
    except:
        continue
        i=int(i)
#     sleep(0.1)
#     i=int(i)
driver.find_element_by_xpath('//*[@id="viewDummy"]').click()

# except:
#     pass
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[3]').click()
# # sleep(2)
# driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
# # sleep(15)
# driver.quit()
# df_list = pd.read_html('https://nregarep2.nic.in/netnrega/dynamic2/ReportGenerated.aspx')
dfs = pd.read_html(driver.page_source)
dfs_first_part = dfs[-1]
# dfs = dfs.T
print(dfs)
# dfs.to_csv('Animal.csv',index=0)
sleep(10)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# [                                                   0   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                Sno.
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                  6
# 11                                                  7
# ...

# %%
dfs_first_part.to_csv("df_firstpart.csv",index=False)

# %%
dfs_first_part.head()
# Out:
#    Sno.            State Name  Total households applied for job card  \
# 0   1.0   ANDAMAN AND NICOBAR                                  48489
# 1   2.0  DADRA & NAGAR HAVELI                                   8176
# 2   3.0           DAMAN & DIU                                      0
# 3   4.0           LAKSHADWEEP                                   8493
# 4   5.0              NAGALAND                                 398035
#
#    Total job cards issued  Total job cards (SC)  Total job cards (ST)  \
# 0                   48485                     4                  3976
# 1                    3554                     1                  3499
# 2                       0                     0                     0
# 3                    8424                     8                  8321
# 4                  397829                  3545                372154
#
#    Total job cards (non-SC/ST)  Total households demanded work  \
# ...

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[31:48]
# print(check_box_trail)
for checkbox in check_box_trail:
    checkbox.click()
driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[1]/label').click() #inside state
driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()

# try:
for i in range (0,33):
    i = str(i+1)
    try:
        driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
        i=int(i)
    except:
        continue
        i=int(i)
#     sleep(0.1)
#     i=int(i)
driver.find_element_by_xpath('//*[@id="viewDummy"]').click()

# except:
#     pass
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[3]').click()
# # sleep(2)
# driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
# # sleep(15)
# driver.quit()
# df_list = pd.read_html('https://nregarep2.nic.in/netnrega/dynamic2/ReportGenerated.aspx')
dfs1 = pd.read_html(driver.page_source)
dfs_last_part = dfs1[-1]
# dfs = dfs.T
print(dfs)
# dfs.to_csv('Animal.csv',index=0)
sleep(10)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# [                                                   0   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                Sno.
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                  6
# 11                                                  7
# ...

# %%
dfs_last_part.to_csv("df_lastpart.csv",index=False)

# %%
dfs_last_part.head()
# Out:
#    Sno.            State Name  Labour exp. (disbursed, Rs. In Lakhs)  \
# 0   1.0   ANDAMAN AND NICOBAR                                   1097
# 1   2.0  DADRA & NAGAR HAVELI                                      0
# 2   3.0           DAMAN & DIU                                      0
# 3   4.0           LAKSHADWEEP                                     96
# 4   5.0              NAGALAND                                  25767
#
#    Material exp. (disbursed, Rs. In Lakhs)  \
# 0                                        5
# 1                                        0
# 2                                        0
# 3                                       12
# 4                                    14067
#
#    Labour exp. (disbursed + pending, Rs. In Lakhs)  \
# 0                                             1099
# 1                                                0
# 2                                                0
# 3                                               96
# ...

# %%
dfs_last_part.drop(columns={'Sno.','State Name'},inplace=True)
dfs_merged=pd.concat([dfs_first_part,dfs_last_part],axis=1,sort=False)
dfs_merged.head()
# Out:
#    Sno.            State Name  Total households applied for job card  \
# 0   1.0   ANDAMAN AND NICOBAR                                  48489
# 1   2.0  DADRA & NAGAR HAVELI                                   8176
# 2   3.0           DAMAN & DIU                                      0
# 3   4.0           LAKSHADWEEP                                   8493
# 4   5.0              NAGALAND                                 398035
#
#    Total job cards issued  Total job cards (SC)  Total job cards (ST)  \
# 0                   48485                     4                  3976
# 1                    3554                     1                  3499
# 2                       0                     0                     0
# 3                    8424                     8                  8321
# 4                  397829                  3545                372154
#
#    Total job cards (non-SC/ST)  Total households demanded work  \
# ...

# %% [markdown]
# # dropdown 1

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    li=['1-10','11-20','21-30','31-40','41-50','51-60','61-70','71-80','81-99','100','>100','>14']
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_1=dfs2
        else:
            data_1[dfs2.columns[2]+li[i-2]]=dfs2.iloc[:,2]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(5)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#
#     Sno.            State Name  \
# 0    1.0   ANDAMAN AND NICOBAR
# 1    2.0  DADRA & NAGAR HAVELI
# 2    3.0           DAMAN & DIU
# 3    4.0           LAKSHADWEEP
# 4    5.0              NAGALAND
# 5    6.0        ANDHRA PRADESH
# 6    7.0     ARUNACHAL PRADESH
# 7    8.0                 ASSAM
# 8    9.0                 BIHAR
# 9   10.0          CHHATTISGARH
# 10  11.0                   GOA
# 11  12.0               GUJARAT
# 12  13.0               HARYANA
# 13  14.0      HIMACHAL PRADESH
# 14  15.0     JAMMU AND KASHMIR
# 15  16.0             JHARKHAND
# 16  17.0             KARNATAKA
# 17  18.0                KERALA
# 18  19.0        MADHYA PRADESH
# 19  20.0           MAHARASHTRA
# 20  21.0               MANIPUR
# 21  22.0             MEGHALAYA
# ...

# %% [markdown]
# DROP_DOWN 1

# %%
data_1.rename(columns = {'Total households completed<br>person-days in range:':'Total households completed<br>person-days in range:1-10'}, inplace = True)

# %%
data_1.head()
# Out:
#    Sno.            State Name  \
# 0   1.0   ANDAMAN AND NICOBAR
# 1   2.0  DADRA & NAGAR HAVELI
# 2   3.0           DAMAN & DIU
# 3   4.0           LAKSHADWEEP
# 4   5.0              NAGALAND
#
#    Total households completed<br>person-days in range:1-10  \
# 0                                               7966
# 1                                                  7
# 2                                                  0
# 3                                                274
# 4                                               4685
#
#    Total households completed<br>person-days in range:11-20  \
# 0                                              23076
# 1                                                 15
# 2                                                  0
# 3                                              14563
# 4                                              67739
#
#    Total households completed<br>person-days in range:21-30  \
# 0                                              35443
# ...

# %%
data_1.to_csv("dropdown_1.csv")

# %% [markdown]
# # drop down 2

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,6):
    i = str(i+1)
    li=['18-30yrs','30-40yrs','40-50yrs','50-60yrs','>60yrs']
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[26:27]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox9"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_2=dfs2
        else:
            data_2[dfs2.columns[2]+li[i-2]]=dfs2.iloc[:,2]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(3)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(1)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#     Sno.            State Name  Total workers employed<br>in age group:
# 0    1.0   ANDAMAN AND NICOBAR                                     2969
# 1    2.0  DADRA & NAGAR HAVELI                                        0
# 2    3.0           DAMAN & DIU                                        0
# 3    4.0           LAKSHADWEEP                                      804
# 4    5.0              NAGALAND                                    65994
# 5    6.0        ANDHRA PRADESH                                   739020
# 6    7.0     ARUNACHAL PRADESH                                    15219
# 7    8.0                 ASSAM                                   229192
# 8    9.0                 BIHAR                                   427043
# ...

# %%
data_2.head()
# Out:
#    Sno.            State Name  Total workers employed<br>in age group:  \
# 0   1.0   ANDAMAN AND NICOBAR                                     2969
# 1   2.0  DADRA & NAGAR HAVELI                                        0
# 2   3.0           DAMAN & DIU                                        0
# 3   4.0           LAKSHADWEEP                                      804
# 4   5.0              NAGALAND                                    65994
#
#    Total workers employed<br>in age group:30-40yrs  \
# 0                                             5108
# 1                                                0
# 2                                                0
# 3                                              641
# 4                                           110841
#
#    Total workers employed<br>in age group:40-50yrs  \
# 0                                             3629
# 1                                                2
# 2                                                0
# ...

# %%
data_2.to_csv("dropdown_2.csv")

# %% [markdown]
# # DROPDOWN 3

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[27:28]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox5"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_3=dfs2
        else:
            data_3[dfs2.columns[2]]=dfs2.iloc[:,2]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(5)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#     Sno.            State Name  Total households demanded<br>work(Apr)
# 0    1.0   ANDAMAN AND NICOBAR                                    3887
# 1    2.0  DADRA & NAGAR HAVELI                                       4
# 2    3.0           DAMAN & DIU                                       0
# 3    4.0           LAKSHADWEEP                                     180
# 4    5.0              NAGALAND                                  319127
# 5    6.0        ANDHRA PRADESH                                       0
# 6    7.0     ARUNACHAL PRADESH                                    3164
# 7    8.0                 ASSAM                                  195627
# 8    9.0                 BIHAR                                  824777
# ...

# %%
data_3.head()
# Out:
#    Sno.            State Name  Total households demanded<br>work(Apr)  \
# 0   1.0   ANDAMAN AND NICOBAR                                    3887
# 1   2.0  DADRA & NAGAR HAVELI                                       4
# 2   3.0           DAMAN & DIU                                       0
# 3   4.0           LAKSHADWEEP                                     180
# 4   5.0              NAGALAND                                  319127
#
#    Total households demanded<br>work(May)  \
# 0                                    3368
# 1                                       1
# 2                                       0
# 3                                     273
# 4                                  272144
#
#    Total households demanded<br>work(Jun)  \
# 0                                    2835
# 1                                       1
# 2                                       0
# 3                                     167
# 4                                  275621
#
# ...

# %%
data_3.to_csv("dropdown_3.csv")

# %% [markdown]
# # Dropdown 4

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[28:29]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox6"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_4=dfs2
        else:
            data_4[dfs2.columns[2]]=dfs2.iloc[:,2]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(5)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#     Sno.            State Name  Total persons demanded work(Apr)
# 0    1.0   ANDAMAN AND NICOBAR                              4261
# 1    2.0  DADRA & NAGAR HAVELI                                 4
# 2    3.0           DAMAN & DIU                                 0
# 3    4.0           LAKSHADWEEP                               185
# 4    5.0              NAGALAND                            326585
# 5    6.0        ANDHRA PRADESH                                 0
# 6    7.0     ARUNACHAL PRADESH                              3248
# 7    8.0                 ASSAM                            218606
# 8    9.0                 BIHAR                           1050465
# 9   10.0          CHHATTISGARH                           1432035
# ...

# %%
data_4.head()
# Out:
#    Sno.            State Name  Total persons demanded work(Apr)  \
# 0   1.0   ANDAMAN AND NICOBAR                              4261
# 1   2.0  DADRA & NAGAR HAVELI                                 4
# 2   3.0           DAMAN & DIU                                 0
# 3   4.0           LAKSHADWEEP                               185
# 4   5.0              NAGALAND                            326585
#
#    Total persons demanded work(May)  Total persons demanded work(Jun)  \
# 0                              3781                              3184
# 1                                 1                                 1
# 2                                 0                                 0
# 3                               278                               169
# 4                            272267                            275622
#
#    Total persons demanded work(Jul)  Total persons demanded work(Aug)  \
# 0                              5041                              4400
# ...

# %%
data_4.to_csv("dropdown_4.csv")

# %% [markdown]
# # Dropdown 5

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[29:30]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox7"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_5=dfs2
        else:
            data_5[dfs2.columns[2]]=dfs2.iloc[:,2]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(5)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#     Sno.            State Name  Total households worked(Apr)
# 0    1.0   ANDAMAN AND NICOBAR                          2044
# 1    2.0  DADRA & NAGAR HAVELI                             2
# 2    3.0           DAMAN & DIU                             0
# 3    4.0           LAKSHADWEEP                           175
# 4    5.0              NAGALAND                        318868
# 5    6.0        ANDHRA PRADESH                       1968854
# 6    7.0     ARUNACHAL PRADESH                          1852
# 7    8.0                 ASSAM                        194444
# 8    9.0                 BIHAR                        803949
# 9   10.0          CHHATTISGARH                        834523
# 10  11.0                   GOA                           704
# ...

# %%
data_5.head()
# Out:
#    Sno.            State Name  Total households worked(Apr)  \
# 0   1.0   ANDAMAN AND NICOBAR                          2044
# 1   2.0  DADRA & NAGAR HAVELI                             2
# 2   3.0           DAMAN & DIU                             0
# 3   4.0           LAKSHADWEEP                           175
# 4   5.0              NAGALAND                        318868
#
#    Total households worked(May)  Total households worked(Jun)  \
# 0                          2641                          3312
# 1                             0                             0
# 2                             0                             0
# 3                           258                           167
# 4                        297316                        268643
#
#    Total households worked(Jul)  Total households worked(Aug)  \
# 0                          4310                          4027
# 1                             0                             0
# ...

# %%
data_5.to_csv("dropdown_5.csv")

# %% [markdown]
# # Dropdown 6

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[30:31]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox8"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_6=dfs2
        else:
            data_6[dfs2.columns[2]]=dfs2.iloc[:,2]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(5)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#
#     Sno.            State Name  Total persons worked(Apr)
# 0    1.0   ANDAMAN AND NICOBAR                      25269
# 1    2.0  DADRA & NAGAR HAVELI                         22
# 2    3.0           DAMAN & DIU                          0
# 3    4.0           LAKSHADWEEP                       2818
# 4    5.0              NAGALAND                    3849725
# 5    6.0        ANDHRA PRADESH                   39804869
# 6    7.0     ARUNACHAL PRADESH                      30324
# 7    8.0                 ASSAM                    2301592
# 8    9.0                 BIHAR                   17448347
# 9   10.0          CHHATTISGARH                   12622589
# 10  11.0                   GOA                       7312
# 11  12.0               GUJARAT                    1779724
# ...

# %%
data_6.to_csv("dropdown_6.csv")

# %%
dfs_merged.head()
# Out:
#    Sno.            State Name  Total households applied for job card  \
# 0   1.0   ANDAMAN AND NICOBAR                                  48489
# 1   2.0  DADRA & NAGAR HAVELI                                   8176
# 2   3.0           DAMAN & DIU                                      0
# 3   4.0           LAKSHADWEEP                                   8493
# 4   5.0              NAGALAND                                 398035
#
#    Total job cards issued  Total job cards (SC)  Total job cards (ST)  \
# 0                   48485                     4                  3976
# 1                    3554                     1                  3499
# 2                       0                     0                     0
# 3                    8424                     8                  8321
# 4                  397829                  3545                372154
#
#    Total job cards (non-SC/ST)  Total households demanded work  \
# ...

# %%
#file.drop(columns={"Unnamed: 0"},inplace=True)

# %%
d1=pd.read_csv("dropdown_1.csv")
d2=pd.read_csv("dropdown_2.csv")
d3=pd.read_csv("dropdown_3.csv")
d4=pd.read_csv("dropdown_4.csv")
d5=pd.read_csv("dropdown_5.csv")
d6=pd.read_csv("dropdown_6.csv")

# %%
d1.head()
# Out:
#    Unnamed: 0  Sno.            State Name  \
# 0           0   1.0   ANDAMAN AND NICOBAR
# 1           1   2.0  DADRA & NAGAR HAVELI
# 2           2   3.0           DAMAN & DIU
# 3           3   4.0           LAKSHADWEEP
# 4           4   5.0              NAGALAND
#
#    Total households completed<br>person-days in range:1-10  \
# 0                                               7966
# 1                                                  7
# 2                                                  0
# 3                                                274
# 4                                               4685
#
#    Total households completed<br>person-days in range:11-20  \
# 0                                              23076
# 1                                                 15
# 2                                                  0
# 3                                              14563
# 4                                              67739
#
# ...

# %%
d1.drop(columns={"Unnamed: 0","Sno.","State Name"},inplace=True)
d2.drop(columns={"Unnamed: 0","Sno.","State Name"},inplace=True)
d3.drop(columns={"Unnamed: 0","Sno.","State Name"},inplace=True)
d4.drop(columns={"Unnamed: 0","Sno.","State Name"},inplace=True)
d5.drop(columns={"Unnamed: 0","Sno.","State Name"},inplace=True)
d6.drop(columns={"Unnamed: 0","Sno.","State Name"},inplace=True)

# %%
combined_2012_13_state=pd.concat([dfs_merged,d1,d2,d3,d4,d5,d6],axis=1,sort=False)

# %%
combined_2012_13_state.head()
# Out:
#    Sno.            State Name  Total households applied for job card  \
# 0   1.0   ANDAMAN AND NICOBAR                                  48489
# 1   2.0  DADRA & NAGAR HAVELI                                   8176
# 2   3.0           DAMAN & DIU                                      0
# 3   4.0           LAKSHADWEEP                                   8493
# 4   5.0              NAGALAND                                 398035
#
#    Total job cards issued  Total job cards (SC)  Total job cards (ST)  \
# 0                   48485                     4                  3976
# 1                    3554                     1                  3499
# 2                       0                     0                     0
# 3                    8424                     8                  8321
# 4                  397829                  3545                372154
#
#    Total job cards (non-SC/ST)  Total households demanded work  \
# ...

# %%
#merge.drop(columns={"Sno.","State Name"},inplace=True)

# %%
#FIRST PART AND LAST PART JOINED

# %%
#combined_2019_20_state=pd.concat([file,merge],axis=1,sort=False)

# %%
combined_2012_13_state.head()
# Out:
#    Sno.            State Name  Total households applied for job card  \
# 0   1.0   ANDAMAN AND NICOBAR                                  48489
# 1   2.0  DADRA & NAGAR HAVELI                                   8176
# 2   3.0           DAMAN & DIU                                      0
# 3   4.0           LAKSHADWEEP                                   8493
# 4   5.0              NAGALAND                                 398035
#
#    Total job cards issued  Total job cards (SC)  Total job cards (ST)  \
# 0                   48485                     4                  3976
# 1                    3554                     1                  3499
# 2                       0                     0                     0
# 3                    8424                     8                  8321
# 4                  397829                  3545                372154
#
#    Total job cards (non-SC/ST)  Total households demanded work  \
# ...

# %%
combined_2012_13_state.to_csv("combined_2012_13_state.csv",index=False)

# %%
c=pd.read_csv("combined_2012_13_state.csv")
c.head()
# Out:
#    Sno.            State Name  Total households applied for job card  \
# 0   1.0   ANDAMAN AND NICOBAR                                  48489
# 1   2.0  DADRA & NAGAR HAVELI                                   8176
# 2   3.0           DAMAN & DIU                                      0
# 3   4.0           LAKSHADWEEP                                   8493
# 4   5.0              NAGALAND                                 398035
#
#    Total job cards issued  Total job cards (SC)  Total job cards (ST)  \
# 0                   48485                     4                  3976
# 1                    3554                     1                  3499
# 2                       0                     0                     0
# 3                    8424                     8                  8321
# 4                  397829                  3545                372154
#
#    Total job cards (non-SC/ST)  Total households demanded work  \
# ...

# %% [markdown]
# # D I S T R I C T

# %% [markdown]
# ## first 25

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[:25]
# print(check_box_trail)
for checkbox in check_box_trail:
    checkbox.click()
driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[1]/label').click() #inside state
driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()


# try:
for i in range (0,33):
    i = str(i+1)
    try:
        driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
        i=int(i)
    except:
        continue
        i=int(i)
#     sleep(0.1)
#     i=int(i)
driver.find_element_by_xpath('//*[@id="viewDummy"]').click()

# except:
#     pass
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[3]').click()
# # sleep(2)
# driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
# # sleep(15)
# driver.quit()
# df_list = pd.read_html('https://nregarep2.nic.in/netnrega/dynamic2/ReportGenerated.aspx')
dfs = pd.read_html(driver.page_source)
dfs2_first_part = dfs[-1]
# dfs = dfs.T
print(dfs)
# dfs.to_csv('Animal.csv',index=0)
sleep(10)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# [                                                    0   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                 Sno.
# ..                                                 ...
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646  Note: Figures shown above are indicative only ...
#
#                                                     1   \
# ...

# %%
dfs2_first_part.head()
# Out:
#    Sno.            State Name             District Name  \
# 0   1.0   ANDAMAN AND NICOBAR                  NICOBARS
# 1   2.0   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2   3.0   ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3   4.0  DADRA & NAGAR HAVELI    DADRA AND NAGAR HAVELI
# 4   5.0           DAMAN & DIU                     DAMAN
#
#    Total households applied for job card  Total job cards issued  \
# 0                                   5149                    5145
# 1                                  18292                   18292
# 2                                  25048                   25048
# 3                                   8176                    3554
# 4                                      0                       0
#
#    Total job cards (SC)  Total job cards (ST)  Total job cards (non-SC/ST)  \
# 0                     4                  3628                         1513
# 1                     0                     0                        18292
# ...

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[31:48]
# print(check_box_trail)
for checkbox in check_box_trail:
    checkbox.click()
driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[1]/label').click() #inside state
driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()


# try:
for i in range (0,33):
    i = str(i+1)
    try:
        driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
        i=int(i)
    except:
        continue
        i=int(i)
#     sleep(0.1)
#     i=int(i)
driver.find_element_by_xpath('//*[@id="viewDummy"]').click()

# except:
#     pass
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[3]').click()
# # sleep(2)
# driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
# # sleep(15)
# driver.quit()
# df_list = pd.read_html('https://nregarep2.nic.in/netnrega/dynamic2/ReportGenerated.aspx')
dfs1 = pd.read_html(driver.page_source)
dfs2_last_part = dfs1[-1]
# dfs = dfs.T
print(dfs)
# dfs.to_csv('Animal.csv',index=0)
sleep(10)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# [                                                    0   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                 Sno.
# ..                                                 ...
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646  Note: Figures shown above are indicative only ...
#
#                                                     1   \
# ...

# %%
dfs2_last_part.drop(columns={'Sno.','State Name','District Name'},inplace=True)
district_merged=pd.concat([dfs2_first_part,dfs2_last_part],axis=1,sort=False)
district_merged
# Out:
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
#      Total households applied for job card  Total job cards issued  \
# 0                                     5149                    5145
# 1                                    18292                   18292
# ...

# %%
district_merged.to_csv("district_merged.csv",index=False)

# %% [markdown]
# # dropdown 1

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    li=['1-10','11-20','21-30','31-40','41-50','51-60','61-70','71-80','81-99','100','>100','>14']
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_1=dfs2
        else:
            data_1[dfs2.columns[3]+li[i-2]]=dfs2.iloc[:,3]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(5)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
# ...

# %%
data_1.rename(columns = {'Total households completed<br>person-days in range:':'Total households completed<br>person-days in range:1-10'}, inplace = True)

# %%
data_1.to_csv("dis_dropdown_1.csv",index=False)

# %%
data_1
# Out:
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
#      Total households completed<br>person-days in range:1-10  \
# 0                                                 1560
# 1                                                 4815
# 2                                                 1591
# ...

# %% [markdown]
# # Dropdown 2

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,6):
    i = str(i+1)
    li=['18-30yrs','30-40yrs','40-50yrs','50-60yrs','>60yrs']
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[26:27]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox9"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_2=dfs2
        else:
            data_2[dfs2.columns[3]+li[i-2]]=dfs2.iloc[:,3]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(3)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(1)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
# ...

# %%
data_2.rename(columns = {'Total workers employed<br>in age group:':'Total workers employed<br>in age group:18-30yrs'}, inplace = True)

# %%
data_2.to_csv("dis_dropdown_2.csv",index=False)

# %%
data_2.head()
# Out:
#    Sno.            State Name             District Name  \
# 0   1.0   ANDAMAN AND NICOBAR                  NICOBARS
# 1   2.0   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2   3.0   ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3   4.0  DADRA & NAGAR HAVELI    DADRA AND NAGAR HAVELI
# 4   5.0           DAMAN & DIU                     DAMAN
#
#    Total workers employed<br>in age group:18-30yrs  \
# 0                                              352
# 1                                             2455
# 2                                              162
# 3                                                0
# 4                                                0
#
#    Total workers employed<br>in age group:30-40yrs  \
# 0                                              546
# 1                                             4204
# 2                                              358
# 3                                                0
# 4                                                0
#
# ...

# %% [markdown]
# # dropdown 3

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[27:28]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox5"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_3=dfs2
        else:
            data_3[dfs2.columns[3]]=dfs2.iloc[:,3]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(5)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
# ...

# %%
data_3
# Out:
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
#      Total households demanded<br>work(Apr)  \
# 0                                       448
# 1                                      1354
# 2                                      2085
# 3                                         4
# ...

# %%
data_3.to_csv("dis_dropdown_3.csv",index=False)

# %% [markdown]
# # dropdown 4

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[28:29]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox6"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_4=dfs2
        else:
            data_4[dfs2.columns[3]]=dfs2.iloc[:,3]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(2)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/87.0.4280.88/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88]
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# ...

# %%
data_4.to_csv("dis_dropdown_4.csv",index=False)

# %% [markdown]
# # dropdown5

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[29:30]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox7"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_5=dfs2
        else:
            data_5[dfs2.columns[3]]=dfs2.iloc[:,3]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(2)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
# ...

# %%
data_5.to_csv("dis_dropdown_5.csv",index=False)

# %% [markdown]
# # dropdown 6

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
# check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[25:26]
# # print(check_box_trail)
# ##for checkbox in check_box_trail:
#     checkbox.click()
# driver.find_element_by_xpath('//*[@id="regionselect"]/option[1]').click()
# for i in range (0,33):
#     i = str(i+1)
#     try:
#         driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
#         i=int(i)
#     except:
#         continue
#         i=int(i)
#     i=int(i)
    
for i in range (1,13):
    i = str(i+1)
    try:
        
        check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[30:31]
        driver.find_element_by_xpath('//*[@id="DdlstFinYear"]/option[10]').click()
        for checkbox in check_box_trail:
            checkbox.click()
        driver.find_element_by_xpath('//*[@id="regionselect"]/option[2]').click()
        for j in range (0,33):
            j = str(j+1)
            try:
                driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+j+']/label').click() #inside state
                j=int(j)
            except:
                continue
                j=int(j)
        j=int(j)
        driver.find_element_by_xpath('//*[@id="DdlstTxtBox8"]/option['+i+']').click() #inside state
        i=int(i)
#         typeOf(i)
        driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
        driver.implicitly_wait(15)
        dfs = pd.read_html(driver.page_source)
        dfs2 = dfs[-1]
        if i==2:
            data_6=dfs2
        else:
            data_6[dfs2.columns[3]]=dfs2.iloc[:,3]
                
                
        dfs2 = dfs[-1]
#                 dfs1.columns[3] = dfs[-1].dfs.loc[:,dfs.columns[2]]
        # dfs = dfs.T
        print(dfs2)
        sleep(2)
        driver.find_element_by_xpath('//*[@id="BtnBack"]').click() #inside state
        sleep(2)
#         driver.find_element_by_xpath('//*[@id="DdlstTxtBox1"]/option['+i+']').click()
    except:
        continue    
#     i=int(i)
driver.quit()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Abhishek\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
#       Sno.            State Name              District Name  \
# 0      1.0   ANDAMAN AND NICOBAR                   NICOBARS
# 1      2.0   ANDAMAN AND NICOBAR   NORTH AND MIDDLE ANDAMAN
# 2      3.0   ANDAMAN AND NICOBAR              SOUTH ANDAMAN
# 3      4.0  DADRA & NAGAR HAVELI     DADRA AND NAGAR HAVELI
# 4      5.0           DAMAN & DIU                      DAMAN
# ..     ...                   ...                        ...
# 633  634.0           WEST BENGAL          PASCHIM MEDINIPUR
# 634  635.0           WEST BENGAL            PURBA MEDINIPUR
# 635  636.0           WEST BENGAL                    PURULIA
# 636  637.0           WEST BENGAL  SILIGURI MAHAKUMA PARISAD
# 637    NaN                   NaN                     Total:
#
#      Total persons worked(Apr)
# ...

# %%
data_6.to_csv("dis_dropdown_6.csv",index=False)

# %%
district_merged.head()
# Out:
#    Sno.            State Name             District Name  \
# 0   1.0   ANDAMAN AND NICOBAR                  NICOBARS
# 1   2.0   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2   3.0   ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3   4.0  DADRA & NAGAR HAVELI    DADRA AND NAGAR HAVELI
# 4   5.0           DAMAN & DIU                     DAMAN
#
#    Total households applied for job card  Total job cards issued  \
# 0                                   5149                    5145
# 1                                  18292                   18292
# 2                                  25048                   25048
# 3                                   8176                    3554
# 4                                      0                       0
#
#    Total job cards (SC)  Total job cards (ST)  Total job cards (non-SC/ST)  \
# 0                     4                  3628                         1513
# 1                     0                     0                        18292
# ...

# %%
d1=pd.read_csv("dis_dropdown_1.csv")
d2=pd.read_csv("dis_dropdown_2.csv")
d3=pd.read_csv("dis_dropdown_3.csv")
d4=pd.read_csv("dis_dropdown_4.csv")
d5=pd.read_csv("dis_dropdown_5.csv")
d6=pd.read_csv("dis_dropdown_6.csv")

# %%
#file2=pd.read_csv("district_merged.csv")

# %%
#file2.head()

# %%
#d6.shape

# %%
d1.drop(columns={"Sno.","State Name","District Name"},inplace=True)
d2.drop(columns={"Sno.","State Name","District Name"},inplace=True)
d3.drop(columns={"Sno.","State Name","District Name"},inplace=True)
d4.drop(columns={"Sno.","State Name","District Name"},inplace=True)
d5.drop(columns={"Sno.","State Name","District Name"},inplace=True)
d6.drop(columns={"Sno.","State Name","District Name"},inplace=True)

# %%
combined_2012_13_district=pd.concat([district_merged,d1,d2,d3,d4,d5,d6],axis=1,sort=False)

# %%
combined_2012_13_district.head()
# Out:
#    Sno.            State Name             District Name  \
# 0   1.0   ANDAMAN AND NICOBAR                  NICOBARS
# 1   2.0   ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2   3.0   ANDAMAN AND NICOBAR             SOUTH ANDAMAN
# 3   4.0  DADRA & NAGAR HAVELI    DADRA AND NAGAR HAVELI
# 4   5.0           DAMAN & DIU                     DAMAN
#
#    Total households applied for job card  Total job cards issued  \
# 0                                   5149                    5145
# 1                                  18292                   18292
# 2                                  25048                   25048
# 3                                   8176                    3554
# 4                                      0                       0
#
#    Total job cards (SC)  Total job cards (ST)  Total job cards (non-SC/ST)  \
# 0                     4                  3628                         1513
# 1                     0                     0                        18292
# ...

# %%
combined_2012_13_district.to_csv("combined_2012_13_district.csv")

# %%
ssssssssssssssssssssssssssssssss

# %% [markdown]
# # BLOCK

# %%
url='https://nregarep2.nic.in/netnrega/dynamic2/dynamicreport_new4.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(20)
check_box_trail= driver.find_elements_by_xpath('//input[@type="checkbox"]')[:25]
# print(check_box_trail)
for checkbox in check_box_trail:
    checkbox.click()
driver.find_element_by_xpath('//*[@id="regionselect"]/option[3]').click()
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[1]/label').click() #inside state

# try:
for i in range (0,33):
    i = str(i+1)
    try:
        driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li['+i+']/label').click() #inside state
        i=int(i)
    except:
        continue
        i=int(i)
#     sleep(0.1)
#     i=int(i)
driver.find_element_by_xpath('//*[@id="viewDummy"]').click()

# except:
#     pass
# driver.find_element_by_xpath('//*[@id="checklist"]/ul/ul/li[3]').click()
# # sleep(2)
# driver.find_element_by_xpath('//*[@id="viewDummy"]').click()
# # sleep(15)
# driver.quit()
# df_list = pd.read_html('https://nregarep2.nic.in/netnrega/dynamic2/ReportGenerated.aspx')
dfs = pd.read_html(driver.page_source)
dfs3_first_part = dfs[-1]
# dfs = dfs.T
print(dfs)
# dfs.to_csv('Animal.csv',index=0)
sleep(25)
driver.quit()
