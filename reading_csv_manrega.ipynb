# %%
import pandas as pd

# %%
df = pd.read_csv('df_state.csv')
df_dict = df.to_dict()

# %%
df = pd.DataFrame.from_dict(df_dict)

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                                                 0
# 1                                                 0
# 2    10                                         0
# 3    11                                    289218
# 4    12                                2266244645
# ..                                              ...
# 293  42                                       NaN
# 294                                             NaN
# 295                         [43 rows x 41 columns]"
# 296                                               8
# 297                                               9
#
#                                                      0  \
# 0                                                  ...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...
