# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# from sqlalchemy import create_engine
# import psycopg2 
# import io

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import matplotlib
from IPython.display import display, HTML
from pandas.io.json import json_normalize
from termcolor import colored
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import string
from Demographics_ETL import extract_data, transform_data, load_data

# %%
excel_path = 'Excel Files/'

# %%
# %%HTML
# <style type="text/css">
#
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
#
# </style>
# Out:
# <style type="text/css">
#
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
#
# </style>

# %%
INDEX_NAME='demographics_v1_test'
TYPE_NAME ='_doc' 
uuid = 5000
from elasticsearch import Elasticsearch
#elastic = Elasticsearch(HOST="localhost",PORT=9200)

# elastic = Elasticsearch([{'host':'142.93.213.146','port':9200}])

# %% [markdown]
# # <b>Sates List<B>

# %% [markdown]
# * Andhra Pradesh
# * Arunachal Pradesh
# * Assam
# * Bihar
# * Chhattisgarh
# * Goa
# * Gujarat
# * Haryana
# * Himachal Pradesh
# * Jammu and Kashmir
# * Jharkhand
# * Karnataka
# * Kerala
# * Madhya Pradesh
# * Maharashtra
# * Manipur
# * Meghalaya
# * Mizoram
# * Nagaland
# * Odisha
# * Punjab
# * Rajasthan
# * Sikkim
# * Tamil Nadu
# * Telangana
# * Tripura
# * Uttar Pradesh
# * Uttarakhand
# * West Bengal
# * All India

# %% [markdown]
# # <b>UT's List<b>

# %% [markdown]
# * Andaman and Nicobar Islands
# * Chandigarh
# * Dadra and Nagar Haveli
# * Daman and Diu
# * Delhi
# * Lakshadweep
# * Puducherry

# %% [markdown]
# # MNREGA -STATE WISE DATA

# %%
main1=pd.read_excel(excel_path + 'MNREGA State data 2011-12.xlsx')
main1=main1.rename(columns={main1.columns[0]:"Year"})
main1=main1.rename(columns={main1.columns[1]:"2012"})
main1 = main1.T
main1.columns=main1.loc["Year"]
main1=main1.drop(["Year"])
main1
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY  PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main2=pd.read_excel(excel_path + 'MNREGA State data 2012-13.xlsx')
main2=main2.rename(columns={main2.columns[0]:"Year"})
main2=main2.rename(columns={main2.columns[1]:"2013"})
main2 = main2.T
main2.columns=main2.loc["Year"]
main2=main2.drop(["Year"])
main2
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY  PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main3=pd.read_excel(excel_path + 'MNREGA State data 2013-14.xlsx')
main3=main3.rename(columns={main3.columns[0]:"Year"})
main3=main3.rename(columns={main3.columns[1]:"2014"})
main3 = main3.T
main3.columns=main3.loc["Year"]
main3=main3.drop(["Year"])
main3
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main4=pd.read_excel(excel_path + 'MNREGA State data 2014-15.xlsx')
main4=main4.rename(columns={main4.columns[0]:"Year"})
main4=main4.rename(columns={main4.columns[1]:"2015"})
main4 = main4.T
main4.columns=main4.loc["Year"]
main4=main4.drop(["Year"])
main4
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main5=pd.read_excel(excel_path + 'MNREGA State data 2015-16.xlsx')
main5=main5.rename(columns={main5.columns[0]:"Year"})
main5=main5.rename(columns={main5.columns[1]:"2016"})
main5 = main5.T
main5.columns=main5.loc["Year"]
main5=main5.drop(["Year"])
main5
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main6=pd.read_excel(excel_path + 'MNREGA State data 2016-17.xlsx')
main6=main6.rename(columns={main6.columns[0]:"Year"})
main6=main6.rename(columns={main6.columns[1]:"2017"})
main6 = main6.T
main6.columns=main6.loc["Year"]
main6=main6.drop(["Year"])
main6
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main7=pd.read_excel(excel_path + 'MNREGA State data 2017-18.xlsx')
main7=main7.rename(columns={main7.columns[0]:"Year"})
main7=main7.rename(columns={main7.columns[1]:"2018"})
main7 = main7.T
main7.columns=main7.loc["Year"]
main7=main7.drop(["Year"])
main7
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main8=pd.read_excel(excel_path + 'MNREGA State data 2018-19.xlsx')
main8=main8.rename(columns={main8.columns[0]:"Year"})
main8=main8.rename(columns={main8.columns[1]:"2019"})
main8 = main8.T
main8.columns=main8.loc["Year"]
main8=main8.drop(["Year"])
main8
# Out:
# Year ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM ANDAMAN AND NICOBAR DADRA & NAGAR HAVELI DAMAN & DIU LAKSHADWEEP NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# ...

# %%
main9=pd.read_excel(excel_path + 'MNREGA State data 2019-20.xlsx')
main9=main9.rename(columns={main9.columns[0]:"Year"})
main9=main9.rename(columns={main9.columns[1]:"2020"})
main9 = main9.T
main9.columns=main9.loc["Year"]
main9=main9.drop(["Year"])
main9 = main9.loc[:,~main9.columns.duplicated()]
main9
# Out:
# Year ANDAMAN AND NICOBAR ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH DADRA & NAGAR HAVELI DAMAN & DIU    GOA  GUJARAT HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA LAKSHADWEEP MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# 2020               33543        8962675            244677  5225284  18296881      3992968                14259           0  37109  4024420  982927          1295574           1327377   4996582   6345492  3639397        8212        7214211     9389675  572605    592889  200157   437342  6892838      70139  1807037  10696319  83828    8523451  630845      17777806     1118723    12749008  138184250

# %%
main10=pd.read_excel(excel_path + 'MNREGA State data 2020-21.xlsx')
main10=main10.rename(columns={main10.columns[0]:"Year"})
main10=main10.rename(columns={main10.columns[1]:"2021"})
main10 = main10.T
main10.columns=main10.loc["Year"]
main10=main10.drop(["Year"])
main10 = main10.loc[:,~main9.columns.duplicated()]
main10
# Out:
# Year ANDAMAN AND NICOBAR ANDHRA PRADESH ARUNACHAL PRADESH    ASSAM     BIHAR CHHATTISGARH DADRA & NAGAR HAVELI DAMAN & DIU    GOA  GUJARAT  HARYANA HIMACHAL PRADESH JAMMU AND KASHMIR JHARKHAND KARNATAKA   KERALA LAKSHADWEEP MADHYA PRADESH MAHARASHTRA MANIPUR MEGHALAYA MIZORAM NAGALAND   ODISHA PUDUCHERRY   PUNJAB RAJASTHAN SIKKIM TAMIL NADU TRIPURA UTTAR PRADESH UTTARAKHAND WEST BENGAL      Total
# 2021               32473        9313074            251695  5295547  19300268      4157567                14327           0  37200  4173872  1036495          1326172           1333859   5315496   6702738  3700720        8217        7411033     9458324  575616    606964  201356   439839  7167332      73067  1866621  11261547  84615    8645933  636582      19712047     1158602    13290484  144589682

# %%
main_df = main1.append([main2,main3,main4,main5,main6,main7,main8])
main_df = main_df.loc[:,~main_df.columns.duplicated()]
main_df = main_df.append([main9,main10])
main_df = main_df.loc[:,~main_df.columns.duplicated()]
main_df.columns = main_df.columns.str.title()
main_df = main_df.rename(columns={main_df.columns[0]:"Andaman and Nicobar Islands"})
main_df = main_df.rename(columns={main_df.columns[1]:"Dadra and Nagar Haveli"})
main_df = main_df.rename(columns={main_df.columns[2]:"Daman and Diu"})
main_df = main_df.rename(columns={main_df.columns[14]:"Jammu and Kashmir"})
main_df = main_df.rename(columns={main_df.columns[-1]:"All India"})
All_States_MNREGA_df = pd.DataFrame(main_df)
All_States_MNREGA_df.reset_index(inplace=True)
All_States_MNREGA_df = All_States_MNREGA_df.rename(columns={All_States_MNREGA_df.columns[0]:"Year"})

All_States_MNREGA_df['Frequency']= 'Yearly'
All_States_MNREGA_df.set_index(['Frequency','Year'],inplace=True)
All_States_MNREGA_df
# Out:
#                Andaman and Nicobar Islands Dadra and Nagar Haveli Daman and Diu Lakshadweep Nagaland Andhra Pradesh Arunachal Pradesh    Assam     Bihar Chhattisgarh    Goa  Gujarat  Haryana Himachal Pradesh Jammu and Kashmir Jharkhand Karnataka   Kerala Madhya Pradesh Maharashtra Manipur Meghalaya Mizoram   Odisha Puducherry   Punjab Rajasthan Sikkim Tamil Nadu Tripura Uttar Pradesh Uttarakhand West Bengal  All India
# Frequency Year
# Yearly    2012                       45396                   7845             0        8254   384478        7166470            163974  3949587  12698704      4402364  32616  4084953   677854          1106662            982755   4040997   5591526  1886774       11977840     6905886  472204    457540  190099  6163936      66941   880093  10022207  80444    8419826  603959      15120532     1037940    11226851  122641399
# ...

# %%
PATH = 'Schemes/MNREGA/Total households applied for job card/'
doc_source={
    "Doc_Source":"MNREGA Portal",
    "Path":PATH,
    "Units":"Number of People",
    "Mode":"State"    
}

# %%
All_States_MNREGA_df_meta = transform_data(All_States_MNREGA_df,doc_source)
All_States_MNREGA_df_meta
# Out:
#                                   Andaman and Nicobar Islands                             Dadra and Nagar Haveli                                      Daman and Diu                                        Lakshadweep                                           Nagaland                                     Andhra Pradesh                                  Arunachal Pradesh                                              Assam                                              Bihar                                       Chhattisgarh                                                Goa                                            Gujarat                                            Haryana                                   Himachal Pradesh                                  Jammu and Kashmir                                          Jharkhand                                          Karnataka                                             Kerala                                     Madhya Pradesh  \
# ...

# %%
uuid = load_data(All_States_MNREGA_df,All_States_MNREGA_df_meta,INDEX_NAME,TYPE_NAME,uuid )
# Out:
# uuid is 5000
# uuid is 5001
# uuid is 5002
# uuid is 5003
# uuid is 5004
# uuid is 5005
# uuid is 5006
# uuid is 5007
# uuid is 5008
# uuid is 5009
# uuid is 5010
# uuid is 5011
# uuid is 5012
# uuid is 5013
# uuid is 5014
# uuid is 5015
# uuid is 5016
# uuid is 5017
# uuid is 5018
# uuid is 5019
# uuid is 5020
# uuid is 5021
# uuid is 5022
# uuid is 5023
# uuid is 5024
# uuid is 5025
# uuid is 5026
# uuid is 5027
# uuid is 5028
# uuid is 5029
# uuid is 5030
# uuid is 5031
# uuid is 5032
# uuid is 5033
